# %% [markdown]
# ### 🔗 Notebook Links
# **Open in Colab:** [Click here](https://colab.research.google.com/drive/My Drive/Colab Notebooks/Data Science/Projects/Centaur_Workflow/notebooks/dummy_test.ipynb)
#
# **Open in NBViewer:** [Click here](https://nbviewer.org/github/Centaur_Workflow/notebooks/dummy_test.ipynb)

# %%
print('Test Notebook for Centaur Workflow')
# Out:
# Test Notebok for Centaur Workflow
